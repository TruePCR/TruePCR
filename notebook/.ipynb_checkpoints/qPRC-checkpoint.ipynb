# %% [markdown]
# qPRC workflow
# =============
# qPRC main workflow in a single, hopefully simple, notebook.
#
# Dependencies
# ------------

# %%
# standard library modules
import os

# external modules
import pandas as pd
import numpy as np

# %% [markdown]
# Global settings
# ----------------

# %%
DATA_LOC = '../data/'

# %% [markdown]
# Parsing the data
# -----------------

# %%
raw = pd.read_csv(os.path.join(DATA_LOC, 'raw_input.csv'))
raw = raw.loc[:, raw.columns[1:]] # kick out the 1st column (numbers from Calc)
raw = raw.replace(',', '.', regex=True).astype('float') # dots as separators, str to float
raw
# Out:
#         V66 GroES    V66 GroES.1    V66 GroES.2      V68 GroES    V68 GroES.1  \
# 0    32308.689577   29115.373606   20779.531717   28197.077164   30108.184079
# 1    32308.689577   29115.373606   20779.531717   28197.077164   30108.184079
# 2    32382.937618   29183.346238   20857.606936   28219.851920   30194.379495
# 3    32505.552416   29296.238279   20983.608030   28257.506508   30333.835784
# 4    32708.035970   29483.729036   21186.949855   28319.762215   30559.459142
# 5    33042.393717   29795.092498   21515.089988   28422.690330   30924.475197
# 6    33594.440664   30312.093206   22044.567736   28592.857148   31514.947650
# 7    34505.638849   31170.260418   22898.725009   28874.167336   32469.936716
# 8    36008.658774   32593.694913   24275.970116   29339.143569   34013.774753
# 9    38484.278578   34950.967044   26494.210092   30107.452071   36507.090835
# 10   42548.762618   38841.103283   30058.431452   31376.094436   40525.189770
# ...

# %% [markdown]
# Modeling
# --------

# %%
# TODO

# %% [markdown]
# Plotting
# ---------

# %%
raw['V66 GroES'].plot()
